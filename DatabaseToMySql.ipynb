# %%
#pip install pandas mysql-connector-python

# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv(r'C:\Users\Michel Diego\Downloads\Database_LeevinGL21052024.csv')
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 df = pd.read_csv(r'C:\Users\Michel Diego\Downloads\Database_LeevinGL21052024.csv')
#       2 df
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:933, in TextFileReader.__init__(self, f, engine, **kwds)
#     930     self.options["has_index_names"] = kwds["has_index_names"]
#     932 self.handles: IOHandles | None = None
# --> 933 self._engine = self._make_engine(f, self.engine)
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:1217, in TextFileReader._make_engine(self, f, engine)
#    1213     mode = "rb"
#    1214 # error: No overload variant of "get_handle" matches argument types
#    1215 # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1216 # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1217 self.handles = get_handle(  # type: ignore[call-overload]
#    1218     f,
#    1219     mode,
#    1220     encoding=self.options.get("encoding", None),
#    1221     compression=self.options.get("compression", None),
#    1222     memory_map=self.options.get("memory_map", False),
#    1223     is_text=is_text,
#    1224     errors=self.options.get("encoding_errors", "strict"),
#    1225     storage_options=self.options.get("storage_options", None),
#    1226 )
#    1227 assert self.handles is not None
#    1228 f = self.handles.handle
#
# File ~\anaconda3\lib\site-packages\pandas\io\common.py:789, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784 elif isinstance(handle, str):
#     785     # Check whether the filename is to be opened in binary mode.
#     786     # Binary mode does not support 'encoding' and 'newline'.
#     787     if ioargs.encoding and "b" not in ioargs.mode:
#     788         # Encoding
# --> 789         handle = open(
#     790             handle,
#     791             ioargs.mode,
#     792             encoding=ioargs.encoding,
#     793             errors=errors,
#     794             newline="",
#     795         )
#     796     else:
#     797         # Binary mode
#     798         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\Michel Diego\\Downloads\\Database_LeevinGL21052024.csv'

# %%
df.columns = df.iloc[0]
df = df[2:]
df
# Out:
# 0    Company     ID                           Property Landlord  \
# 2     Leevin   Erin            North Great 43 - School     Neil
# 3     Leevin  G1103  Gardiner Street Middle 24 - Apt 1     Neil
# 4     Leevin  G1103  Gardiner Street Middle 24 - Apt 1     Neil
# 5     Leevin  G1103  Gardiner Street Middle 24 - Apt 1     Neil
# 6     Leevin  G1103  Gardiner Street Middle 24 - Apt 1     Neil
# ...      ...    ...                                ...      ...
# 3155     NaN    NaN                                NaN      NaN
# 3156     NaN    NaN                                NaN      NaN
# 3157     NaN    NaN                                NaN      NaN
# 3158     NaN    NaN                                NaN      NaN
# 3159     NaN    NaN                                NaN      NaN
#
# 0               Group                           Address    City Zone  \
# 2                 NaN    43 North Great George's Street  Dublin  D01
# 3     Gardiner Street  24 Gardiner Street Middle, Apt 1  Dublin  D01
# 4     Gardiner Street  24 Gardiner Street Middle, Apt 1  Dublin  D01
# 5     Gardiner Street  24 Gardiner Street Middle, Apt 1  Dublin  D01
# 6     Gardiner Street  24 Gardiner Street Middle, Apt 1  Dublin  D01
# ...               ...                               ...     ...  ...
# 3155              NaN                               NaN     NaN  NaN
# 3156              NaN                               NaN     NaN  NaN
# 3157              NaN                               NaN     NaN  NaN
# 3158              NaN                               NaN     NaN  NaN
# 3159              NaN                               NaN     NaN  NaN
#
# 0      Eircode Room info Included Bills # of bathrooms #REF! #REF!   Merge  \
# 2     D01 K023       NaN            NaN            NaN     1   NaN  Leevin
# 3     D01 E084       NaN            NaN     1 bathroom     7     5   Merge
# 4     D01 E084       NaN            NaN     1 bathroom     7     5   Merge
# 5     D01 E084       NaN            NaN     1 bathroom     7     2   Merge
# 6     D01 E084       NaN            NaN     1 bathroom     7     2   Merge
# ...        ...       ...            ...            ...   ...   ...     ...
# 3155       NaN       NaN            NaN            NaN   NaN   NaN     NaN
# 3156       NaN       NaN            NaN            NaN   NaN   NaN     NaN
# 3157       NaN       NaN            NaN            NaN   NaN   NaN     NaN
# 3158       NaN       NaN            NaN            NaN   NaN   NaN     NaN
# 3159       NaN       NaN            NaN            NaN   NaN   NaN     NaN
#
# 0    Gender   Vacancy ID Group Room Type Room        Property Type  \
# 2       NaN          NaN     School    School  Home (entire house)
# 3       NaN  GA24AP01B11   Room 1.1      Twin  Home (entire house)
# 4       NaN  GA24AP01B12   Room 1.2      Twin  Home (entire house)
# 5       NaN  GA24AP01B21   Room 2.1      Twin  Home (entire house)
# 6       NaN  GA24AP01B22   Room 2.2      Twin  Home (entire house)
# ...     ...          ...        ...       ...                  ...
# 3155    NaN          NaN        NaN       NaN                  NaN
# 3156    NaN          NaN        NaN       NaN                  NaN
# 3157    NaN          NaN        NaN       NaN                  NaN
# 3158    NaN          NaN        NaN       NaN                  NaN
# 3159    NaN          NaN        NaN       NaN                  NaN
#
# 0    Vacancy Status Vacancy Status Current Price Base Price (2023) Proj. 2024  \
# 2             Close              1     17,083.33         17,083.33  17,425.00
# 3             Close              4      2,448.00          2,400.00   2,448.00
# 4             Close              1          0.00              0.00       0.00
# 5             Close              1          0.00              0.00       0.00
# 6             Close              1          0.00              0.00       0.00
# ...             ...            ...           ...               ...        ...
# 3155            NaN            NaN           NaN               NaN        NaN
# 3156            NaN            NaN           NaN               NaN        NaN
# 3157            NaN            NaN           NaN               NaN        NaN
# 3158            NaN            NaN           NaN               NaN        NaN
# 3159            NaN            NaN           NaN               NaN        NaN
#
# 0    Proj. 2025 Proj. 2026 Renovação Aplicada  PROJECTION Proj. month  \
# 2     17,774.00  18,129.00                 NaN        NaN         NaN
# 3      2,497.00   2,547.00  December Email ok    2,448.00           9
# 4          0.00       0.00  December Email ok         NaN           9
# 5          0.00       0.00  December Email ok         NaN           9
# 6          0.00       0.00                 NaN        NaN           9
# ...         ...        ...                 ...        ...         ...
# 3155        NaN        NaN                 NaN        NaN         NaN
# 3156        NaN        NaN                 NaN        NaN         NaN
# 3157        NaN        NaN                 NaN        NaN         NaN
# 3158        NaN        NaN                 NaN        NaN         NaN
# 3159        NaN        NaN                 NaN        NaN         NaN
#
# 0    Deposit Amount Booking Code                     Customer  Entry Date  \
# 2         17,083.33         6414  Erin School - Lucas Finelli  01/06/2021
# 3          2,400.00        16160                Madhav Kalra   22/02/2024
# 4              0.00        16161             Herin Bipin Vora  22/10/2023
# 5              0.00        16162       Vinayak Kantaram Hinge  22/10/2023
# 6              0.00        16163          Pratik Arjun Gadkar  22/10/2023
# ...             ...          ...                          ...         ...
# 3155            NaN          NaN                          NaN         NaN
# 3156            NaN          NaN                          NaN         NaN
# 3157            NaN          NaN                          NaN         NaN
# 3158            NaN          NaN                          NaN         NaN
# 3159            NaN          NaN                          NaN         NaN
#
# 0    Expired Date Contract duration Total duration of contract Rent day  Year  \
# 2      01/12/2024          12 meses          42 Months 19 Days       21  2024
# 3      21/06/2024           4 meses                  4 Months        22  2024
# 4      21/06/2024           4 meses            8 Months 3 Days       22  2024
# 5      21/06/2024           4 meses            8 Months 3 Days       22  2024
# 6      21/06/2024           4 meses            8 Months 3 Days       22  2024
# ...           ...               ...                        ...      ...   ...
# 3155          NaN               NaN                        NaN      NaN   NaN
# 3156          NaN               NaN                        NaN      NaN   NaN
# 3157          NaN               NaN                        NaN      NaN   NaN
# 3158          NaN               NaN                        NaN      NaN   NaN
# 3159          NaN               NaN                        NaN      NaN   NaN
#
# 0    Month Last Notice Date Last Open Date Vacancy Abandonement  \
# 2       12              NaN            NaN                  NaN
# 3        6              NaN            NaN                  NaN
# 4        6              NaN            NaN                  NaN
# 5        6              NaN            NaN                  NaN
# 6        6              NaN            NaN                  NaN
# ...    ...              ...            ...                  ...
# 3155   NaN              NaN            NaN                  NaN
# 3156   NaN              NaN            NaN                  NaN
# 3157   NaN              NaN            NaN                  NaN
# 3158   NaN              NaN            NaN                  NaN
# 3159   NaN              NaN            NaN                  NaN
#
# 0    Status of Payment Status deposito                                Note  \
# 2                 Paid        DESCONTO                                 NaN
# 3                  NaN             NaN  criado novo booking Leevin  - 7109
# 4                  NaN             NaN                                 NaN
# 5                  NaN             NaN                                 NaN
# 6                  NaN             NaN                                 NaN
# ...                ...             ...                                 ...
# 3155               NaN             NaN                                 NaN
# 3156               NaN             NaN                                 NaN
# 3157               NaN             NaN                                 NaN
# 3158               NaN             NaN                                 NaN
# 3159               NaN             NaN                                 NaN
#
# 0     8.0 Entry Month Entry Year
# 2     NaN           6       2021
# 3     NaN           2       2024
# 4     NaN          10       2023
# 5     NaN          10       2023
# 6     NaN          10       2023
# ...   ...         ...        ...
# 3155  NaN         NaN        NaN
# 3156  NaN         NaN        NaN
# 3157  NaN         NaN        NaN
# 3158  NaN         NaN        NaN
# 3159  NaN         NaN        NaN
#
# [3158 rows x 49 columns]

# %%
df.columns
# Out:
# Index(['Company', 'ID', 'Property', 'Landlord', 'Group', 'Address', 'City',
#        'Zone', 'Eircode', 'Room info', 'Included Bills', '# of bathrooms',
#        '#REF!', '#REF!.1', 'Merge', 'Gender', 'Vacancy ID', 'Group Room',
#        'Type Room', 'Property Type', 'Vacancy Status', 'Vacancy Status.1',
#        'Current_Price', 'Base Price (2023)', 'Proj. 2024', 'Proj. 2025',
#        'Proj. 2026', 'Renovação Aplicada ', 'PROJECTION', 'Proj. month',
#        'Deposit Amount', 'Booking Code', 'Customer', 'Entry Date',
#        'Expired Date', 'Contract duration', 'Total duration of contract',
#        'Rent day', 'Year', 'Month', 'Last Notice Date', 'Last Open Date',
#        'Vacancy Abandonement', 'Func. Leevin', 'Status of Payment',
#        'Status deposito', 'Note', '12', 'Entry Month', 'Entry Year'],
#       dtype='object')

# %%
df = df.drop('Renovação Aplicada ', axis=1)
df
# Out:
#      Company     ID                           Property Landlord  \
# 0     Leevin  Cream         The Barley House - Factory        -
# 1     Leevin   Erin                               Erin     Neil
# 2     Leevin  G1103  Gardiner Street Middle 24 - Apt 1     Neil
# 3     Leevin  G1103  Gardiner Street Middle 24 - Apt 1     Neil
# 4     Leevin  G1103  Gardiner Street Middle 24 - Apt 1     Neil
# ...      ...    ...                                ...      ...
# 3339     NaN    NaN                                NaN      NaN
# 3340     NaN    NaN                                NaN      NaN
# 3341     NaN    NaN                                NaN      NaN
# 3342     NaN    NaN                                NaN      NaN
# 3343     NaN    NaN                                NaN      NaN
#
#                 Group                                            Address  \
# 0                 NaN  Block A The Barley House, 90-97 Cork St, The L...
# 1                 NaN                     43 North Great George's Street
# 2     Gardiner Street                   24 Gardiner Street Middle, Apt 1
# 3     Gardiner Street                   24 Gardiner Street Middle, Apt 1
# 4     Gardiner Street                   24 Gardiner Street Middle, Apt 1
# ...               ...                                                ...
# 3339              NaN                                                NaN
# 3340              NaN                                                NaN
# 3341              NaN                                                NaN
# 3342              NaN                                                NaN
# 3343              NaN                                                NaN
#
#         City Zone   Eircode Room info Included Bills # of bathrooms  #REF!  \
# 0     Dublin  D08  D08 N5PE       NaN            NaN            NaN    1.0
# 1     Dublin  D01  D01 K023       NaN            NaN            NaN    1.0
# 2     Dublin  D01  D01 E084       NaN            NaN     1 bathroom    7.0
# 3     Dublin  D01  D01 E084       NaN            NaN     1 bathroom    7.0
# 4     Dublin  D01  D01 E084       NaN            NaN     1 bathroom    7.0
# ...      ...  ...       ...       ...            ...            ...    ...
# 3339     NaN  NaN       NaN       NaN            NaN            NaN    NaN
# 3340     NaN  NaN       NaN       NaN            NaN            NaN    NaN
# 3341     NaN  NaN       NaN       NaN            NaN            NaN    NaN
# 3342     NaN  NaN       NaN       NaN            NaN            NaN    NaN
# 3343     NaN  NaN       NaN       NaN            NaN            NaN    NaN
#
#       #REF!.1   Merge Gender   Vacancy ID Group Room Type Room  \
# 0         NaN  Leevin    NaN          TBH    Factory   Factory
# 1         NaN  Leevin    NaN          NaN     School    School
# 2         5.0   Merge    NaN  GA24AP01B11   Room 1.1      Twin
# 3         5.0   Merge    NaN  GA24AP01B12   Room 1.2      Twin
# 4         2.0   Merge   Male  GA24AP01B21   Room 2.1      Twin
# ...       ...     ...    ...          ...        ...       ...
# 3339      NaN     NaN    NaN          NaN        NaN       NaN
# 3340      NaN     NaN    NaN          NaN        NaN       NaN
# 3341      NaN     NaN    NaN          NaN        NaN       NaN
# 3342      NaN     NaN    NaN          NaN        NaN       NaN
# 3343      NaN     NaN    NaN          NaN        NaN       NaN
#
#             Property Type Vacancy Status  Vacancy Status.1  Current_Price  \
# 0                    Home         Return               1.0            NaN
# 1     Home (entire house)          Close               1.0       17083.33
# 2     Home (entire house)         Ending               4.0         612.00
# 3     Home (entire house)         Ending               1.0         612.00
# 4     Home (entire house)         Notice               1.0         612.00
# ...                   ...            ...               ...            ...
# 3339                  NaN            NaN               NaN            NaN
# 3340                  NaN            NaN               NaN            NaN
# 3341                  NaN            NaN               NaN            NaN
# 3342                  NaN            NaN               NaN            NaN
# 3343                  NaN            NaN               NaN            NaN
#
#       Base Price (2023)  Proj. 2024  Proj. 2025  Proj. 2026 PROJECTION  \
# 0                   NaN         NaN         NaN         NaN        NaN
# 1              17083.33     17425.0     17774.0     18129.0        NaN
# 2               2400.00      2448.0      2497.0      2547.0       2448
# 3                  0.00         0.0         0.0         0.0        NaN
# 4                  0.00         0.0         0.0         0.0        NaN
# ...                 ...         ...         ...         ...        ...
# 3339                NaN         NaN         NaN         NaN        NaN
# 3340                NaN         NaN         NaN         NaN        NaN
# 3341                NaN         NaN         NaN         NaN        NaN
# 3342                NaN         NaN         NaN         NaN        NaN
# 3343                NaN         NaN         NaN         NaN        NaN
#
#      Proj. month Deposit Amount Booking Code                     Customer  \
# 0            NaN            NaN          NaN                          NaN
# 1            NaN       17083.33         6414  Erin School - Lucas Finelli
# 2              9         600.00        16160                Madhav Kalra
# 3              9         600.00        17449               Akshit Mistry
# 4              9         600.00        16162       Vinayak Kantaram Hinge
# ...          ...            ...          ...                          ...
# 3339         NaN            NaN          NaN                          NaN
# 3340         NaN            NaN          NaN                          NaN
# 3341         NaN            NaN          NaN                          NaN
# 3342         NaN            NaN          NaN                          NaN
# 3343         NaN            NaN          NaN                          NaN
#
#       Entry Date Expired Date Contract duration Total duration of contract  \
# 0            NaN          NaN               NaN                        NaN
# 1     01/06/2021   01/12/2024          12 meses          42 Months 19 Days
# 2     22/02/2024   21/06/2024           4 meses                  4 Months
# 3     22/03/2024   21/06/2024           3 meses            3 Months 1 Days
# 4     22/10/2023   21/06/2024           4 meses            8 Months 3 Days
# ...          ...          ...               ...                        ...
# 3339         NaN          NaN               NaN                        NaN
# 3340         NaN          NaN               NaN                        NaN
# 3341         NaN          NaN               NaN                        NaN
# 3342         NaN          NaN               NaN                        NaN
# 3343         NaN          NaN               NaN                        NaN
#
#       Rent day  Year Month  Last Notice Date  Last Open Date  \
# 0         21.0   NaN   NaN               NaN             NaN
# 1         21.0  2024    12               NaN             NaN
# 2         22.0  2024     6               NaN             NaN
# 3         22.0  2024     6               NaN             NaN
# 4         22.0  2024     6           45466.0         45466.0
# ...        ...   ...   ...               ...             ...
# 3339       NaN   NaN   NaN               NaN             NaN
# 3340       NaN   NaN   NaN               NaN             NaN
# 3341       NaN   NaN   NaN               NaN             NaN
# 3342       NaN   NaN   NaN               NaN             NaN
# 3343       NaN   NaN   NaN               NaN             NaN
#
#      Vacancy Abandonement Func. Leevin Status of Payment Status deposito  \
# 0                     NaN          NaN              Paid        DESCONTO
# 1                     NaN          NaN              Paid        DESCONTO
# 2                     NaN          NaN               NaN             NaN
# 3                     NaN          NaN               NaN             NaN
# 4                     NaN          NaN               NaN             NaN
# ...                   ...          ...               ...             ...
# 3339                  NaN          NaN               NaN             NaN
# 3340                  NaN          NaN               NaN             NaN
# 3341                  NaN          NaN               NaN             NaN
# 3342                  NaN          NaN               NaN             NaN
# 3343                  NaN          NaN               NaN             NaN
#
#                                     Note  12 Entry Month Entry Year
# 0                                    NaN NaN         NaN        NaN
# 1                                    NaN NaN           6       2021
# 2     criado novo booking Leevin  - 7109 NaN           2       2024
# 3                                    NaN NaN           3       2024
# 4                                    NaN NaN          10       2023
# ...                                  ...  ..         ...        ...
# 3339                                 NaN NaN         NaN        NaN
# 3340                                 NaN NaN         NaN        NaN
# 3341                                 NaN NaN         NaN        NaN
# 3342                                 NaN NaN         NaN        NaN
# 3343                                 NaN NaN         NaN        NaN
#
# [3344 rows x 49 columns]

# %%
import pandas as pd
from sqlalchemy import create_engine

# Read CSV file into a DataFrame
#df = pd.read_csv(r'C:\Users\Michel Diego\Downloads\Database_LeevinGL19052024.csv')

# Define your MySQL server connection details
username = 'root'
password = 'Md502386'
hostname = 'localhost'  # Or your MySQL server IP address
port = '3306'  # Default MySQL port is 3306
database = 'dataleevingl'

# Create a connection string
connection_string = f'mysql+mysqlconnector://{username}:{password}@{hostname}:{port}/{database}'

# Establish a connection to the MySQL database
engine = create_engine(connection_string)

# Write DataFrame to MySQL database
df.to_sql(name='database_leevingl21052024', con=engine, if_exists='replace', index=False)

# Dispose the engine to release the connection resources
engine.dispose()
